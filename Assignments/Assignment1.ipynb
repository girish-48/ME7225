# %% [markdown]
# # Assignment 1
#
# module to find the fourier transformation of Square wave, Triangular wave, and Sawtooth wave

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt 
from scipy import integrate
